# %%
import numpy as np  
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
filepath = r'C:\Users\parim\Downloads\Advertising (1).csv' 
df = pd.read_csv(filepath)

# %%
df = df.drop('ID',axis=1)

# %%
X=df.drop('Sales',axis=1)

# %%
y=df['Sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train=scaler.transform(X_train)

# %% [markdown]
# X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model=Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)#higher is better in ml generally but in mean sqaured error low value i better than high value so we use neg mean sqaured error cv=5 cross validation 5 higher score is better

# %%
score
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(score.mean())#positive mean sqaure error
# Out:
# 8.215396464543607

# %%
model_two=Ridge(alpha=1)

# %%
score=cross_val_score(model_two,X_train,y_train,scoring='neg_mean_squared_error',cv=5)#higher is better in ml generally but in mean sqaured error low value i better than high value so we use neg mean sqaured error cv=5 cross validation 5 higher score is better

# %%
abs(score.mean())#positive mean sqaure error
# Out:
# 3.344839296530695

# %%
model_two.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
# y_pred=model.predict(X_test)

# %%
# from sklearn.metrics import mean_squared_error

# %%
# mean_squared_error(y_test,y_pred)

# %%
## CREATE X and y
X = df.drop('Sales',axis=1)
y = df['Sales']

# TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# SCALE DATA
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model=Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_validate

scores = cross_validate(model, X_train, y_train, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'], cv=10)

# %%
scores
# Out:
# {'fit_time': array([0.00100565, 0.00102019, 0.        , 0.00101066, 0.        ,
#         0.0009985 , 0.00100064, 0.00100136, 0.00099421, 0.00099945]),
#  'score_time': array([0.00102639, 0.        , 0.0010047 , 0.0009985 , 0.00299788,
#         0.00099945, 0.        , 0.00100446, 0.        , 0.        ]),
#  'test_neg_mean_squared_error': array([ -6.06067062, -10.62703078,  -3.99342608,  -5.00949402,
#          -9.14179955, -13.08625636,  -3.83940454,  -9.05878567,
#          -9.05545685,  -5.77888211]),
#  'test_neg_mean_absolute_error': array([-1.8102116 , -2.54195751, -1.46959386, -1.86276886, -2.52069737,
#         -2.45999491, -1.45197069, -2.37739501, -2.44334397, -1.89979708])}

# %%
scores=pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001006    0.001026                    -6.060671
# 1  0.001020    0.000000                   -10.627031
# 2  0.000000    0.001005                    -3.993426
# 3  0.001011    0.000998                    -5.009494
# 4  0.000000    0.002998                    -9.141800
# 5  0.000998    0.000999                   -13.086256
# 6  0.001001    0.000000                    -3.839405
# 7  0.001001    0.001004                    -9.058786
# 8  0.000994    0.000000                    -9.055457
# 9  0.000999    0.000000                    -5.778882
#
#    test_neg_mean_absolute_error
# 0                     -1.810212
# 1                     -2.541958
# 2                     -1.469594
# 3                     -1.862769
# 4                     -2.520697
# 5                     -2.459995
# 6                     -1.451971
# 7                     -2.377395
# 8                     -2.443344
# 9                     -1.899797

# %%
scores.mean()
# Out:
# fit_time                        0.000803
# score_time                      0.000803
# test_neg_mean_squared_error    -7.565121
# test_neg_mean_absolute_error   -2.083773
# dtype: float64

# %%
model=Ridge(alpha=1)

# %%
scores = cross_validate(model, X_train, y_train, scoring=['neg_mean_squared_error', 'neg_mean_absolute_error'], cv=10)

# %%
scores=pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.000505    0.001023                    -2.962508
# 1  0.000000    0.001029                    -3.057378
# 2  0.001028    0.001027                    -2.173740
# 3  0.001586    0.000000                    -0.833034
# 4  0.000000    0.000999                    -3.464018
# 5  0.001511    0.000506                    -8.232647
# 6  0.001053    0.000000                    -1.905864
# 7  0.001010    0.000998                    -2.765048
# 8  0.000998    0.000000                    -4.989505
# 9  0.001000    0.000000                    -2.846438
#
#    test_neg_mean_absolute_error
# 0                     -1.457174
# 1                     -1.555308
# 2                     -1.238770
# 3                     -0.768938
# 4                     -1.434489
# 5                     -1.494316
# 6                     -1.081362
# 7                     -1.250011
# 8                     -1.580971
# 9                     -1.223326

# %%
scores.mean()
# Out:
# fit_time                        0.000869
# score_time                      0.000558
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
#y-final_pred=model.predict(X_test)
#mean_squared_error(y-test,y-final_pred)

#simple problem -cross_val_score,huge problem-cross_validatemore computational time
