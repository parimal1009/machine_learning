# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath=r'C:\Users\parim\Downloads\Advertising.csv'
df=pd.read_csv(filepath)

# %%
df.head()
# Out:
#    ID     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4
# 2   3   17.2   45.9       69.3    9.3
# 3   4  151.5   41.3       58.5   18.5
# 4   5  180.8   10.8       58.4   12.9

# %%
df['total_spend'] =  df['TV']+df['Radio']+df['Newspaper']

# %%
df.head()
# Out:
#    ID     TV  Radio  Newspaper  Sales  total_spend
# 0   1  230.1   37.8       69.2   22.1        337.1
# 1   2   44.5   39.3       45.1   10.4        128.9
# 2   3   17.2   45.9       69.3    9.3        132.4
# 3   4  151.5   41.3       58.5   18.5        251.3
# 4   5  180.8   10.8       58.4   12.9        250.0

# %%
sns.scatterplot(data=df,x='total_spend',y='Sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='Sales'>

# %%
sns.regplot(data=df,x='total_spend',y='Sales')
# Out:
# <Axes: xlabel='total_spend', ylabel='Sales'>

# %%
x=df['total_spend']
y=df['Sales']

# %%
# help(np.polyfit)

# %%
np.polyfit(x,y,deg=1)#y=mx+b,#y=B1x+b0 these are the following results we are gettign
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend=np.linspace(0,500,100)

# %%
predicted_sales = 0.04868788*potential_spend + 4.24302822#y=b1x+b0

# %%
sns.scatterplot(x='total_spend',y='Sales',data=df)
plt.plot(potential_spend,predicted_sales,color='red')

# %%
spend=200
predicted_sales = 0.04868788*spend+4.24302822

# %%
predicted_sales
# Out:
# 13.98060422

# %%
np.polyfit(x,y,3)#x^3,x^2,x,y
# Out:
# array([ 3.07615033e-07, -1.89392449e-04,  8.20886302e-02,  2.70495053e+00])

# %%
#y=b1x+b0
#we actually solved
#y=B3x**3+B2*x**2+b1x+b0

# %%
pot_spend=np.linspace(0,500,100)

# %%
pred_sales = 3.07615033e-07*pot_spend**3+-1.89392449e-04*pot_spend**2+8.20886302e-02*pot_spend+2.70495053e+00

# %%
sns.scatterplot(x='total_spend',y='Sales',data=df)
plt.plot(pot_spend,pred_sales,color='red')
